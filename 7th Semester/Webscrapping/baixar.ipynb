# %%
import requests
res = requests.get('https://livrariadigital.aflip.in/975794a3-878c-4e72-a975-d1691048c384')

# %%
import requests

def download_image(url, destination):
    response = requests.get(url, stream=True)
    response.raise_for_status()
    
    with open(destination, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)
            
    print('Image downloaded successfully!')

# Example usage
image_url = 'https://livrariadigital.aflip.in/975794a3-878c-4e72-a975-d1691048c384'
save_path = './image.jpg'
download_image(image_url, save_path)
# Out:
# Image downloaded successfully!

# %%
import urllib.request

def download_image_blob(url, destination):
    urllib.request.urlretrieve(url, destination)
    print('Image downloaded successfully!')

image_url = 'blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd'
save_path = './image2.jpg'
download_image(image_url, save_path)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[7], line 9
#       7 image_url = 'blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd'
#       8 save_path = './image2.jpg'
# ----> 9 download_image(image_url, save_path)
#
# Cell In[6], line 4, in download_image(url, destination)
#       3 def download_image(url, destination):
# ----> 4     response = requests.get(url, stream=True)
#       5     response.raise_for_status()
#       7     with open(destination, 'wb') as file:
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\sessions.py:695, in Session.send(self, request, **kwargs)
#     692 hooks = request.hooks
#     694 # Get the appropriate adapter to use
# --> 695 adapter = self.get_adapter(url=request.url)
#     697 # Start time (approximately) of the request
#     698 start = preferred_clock()
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\sessions.py:792, in Session.get_adapter(self, url)
#     789         return adapter
#     791 # Nothing matches :-/
# --> 792 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for 'blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd'

# %%
import requests
import browser_cookie3

def download_image(url, destination):
    cookies = browser_cookie3.load()
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers, cookies=cookies, stream=True)
    response.raise_for_status()

    with open(destination, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

    print("Image downloaded successfully!")

# Example usage
image_url = "blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd"
save_path = "./image3.jpg"
download_image(image_url, save_path)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[8], line 19
#      17 image_url = "blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd"
#      18 save_path = "./image3.jpg"
# ---> 19 download_image(image_url, save_path)
#
# Cell In[8], line 7, in download_image(url, destination)
#       5 cookies = browser_cookie3.load()
#       6 headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
# ----> 7 response = requests.get(url, headers=headers, cookies=cookies, stream=True)
#       8 response.raise_for_status()
#      10 with open(destination, 'wb') as file:
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\sessions.py:695, in Session.send(self, request, **kwargs)
#     692 hooks = request.hooks
#     694 # Get the appropriate adapter to use
# --> 695 adapter = self.get_adapter(url=request.url)
#     697 # Start time (approximately) of the request
#     698 start = preferred_clock()
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\requests\sessions.py:792, in Session.get_adapter(self, url)
#     789         return adapter
#     791 # Nothing matches :-/
# --> 792 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for 'blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd'

# %%
from selenium import webdriver

def download_image(blob_url, destination):
    options = webdriver.ChromeOptions()
    options.add_argument("--headless")  # Run Chrome in headless mode
    options.add_argument("--disable-gpu")
    driver = webdriver.Chrome(options=options)

    driver.get(blob_url)
    image_element = driver.find_element('img')
    image_src = image_element.get_attribute('src')

    response = requests.get(image_src, stream=True)
    response.raise_for_status()

    with open(destination, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

    driver.quit()
    print("Image downloaded successfully!")

# Example usage
blob_url = "blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd"
save_path = "./image3.jpg"
download_image(blob_url, save_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 26
#      24 blob_url = "blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd"
#      25 save_path = "./image3.jpg"
# ---> 26 download_image(blob_url, save_path)
#
# Cell In[9], line 10, in download_image(blob_url, destination)
#       7 driver = webdriver.Chrome(options=options)
#       9 driver.get(blob_url)
# ---> 10 image_element = driver.find_element_by_tag_name('img')
#      11 image_src = image_element.get_attribute('src')
#      13 response = requests.get(image_src, stream=True)
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_tag_name'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep

def download_image(blob_url, destination):
    options = webdriver.ChromeOptions()
    # options.add_argument("--headless")  # Run Chrome in headless mode
    options.add_argument("--disable-gpu")
    driver = webdriver.Chrome(options=options)
    sleep(5)

    driver.get(blob_url)
    sleep(5)
    image_element = driver.find_element(By.CSS_SELECTOR, "#canvas [page] img")
    image_src = image_element.get_attribute("src")

    response = requests.get(image_src, stream=True)
    response.raise_for_status()

    with open(destination, "wb") as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

    driver.quit()
    print("Image downloaded successfully!")

# Example usage
blob_url = "blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd"
save_path = "./image6.jpg"
download_image(blob_url, save_path)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[2], line 30
#      28 blob_url = "blob:https://livrariadigital.aflip.in/91729342-a66e-4508-81c1-5891b0db7ddd"
#      29 save_path = "./image6.jpg"
# ---> 30 download_image(blob_url, save_path)
#
# Cell In[2], line 14, in download_image(blob_url, destination)
#      12 driver.get(blob_url)
#      13 sleep(5)
# ---> 14 image_element = driver.find_element(By.CSS_SELECTOR, "#canvas [page] img")
#      15 image_src = image_element.get_attribute("src")
#      17 response = requests.get(image_src, stream=True)
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#canvas [page] img"}
#   (Session info: chrome=114.0.5735.134)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00B5A813+48355]
# 	(No symbol) [0x00AEC4B1]
# 	(No symbol) [0x009F5358]
# 	(No symbol) [0x00A209A5]
# 	(No symbol) [0x00A20B3B]
# 	(No symbol) [0x00A4E232]
# 	(No symbol) [0x00A3A784]
# 	(No symbol) [0x00A4C922]
# 	(No symbol) [0x00A3A536]
# 	(No symbol) [0x00A182DC]
# 	(No symbol) [0x00A193DD]
# 	GetHandleVerifier [0x00DBAABD+2539405]
# 	GetHandleVerifier [0x00DFA78F+2800735]
# 	GetHandleVerifier [0x00DF456C+2775612]
# 	GetHandleVerifier [0x00BE51E0+616112]
# 	(No symbol) [0x00AF5F8C]
# 	(No symbol) [0x00AF2328]
# 	(No symbol) [0x00AF240B]
# 	(No symbol) [0x00AE4FF7]
# 	BaseThreadInitThunk [0x764B6BA9+25]
# 	RtlGetFullPathName_UEx [0x77C48F9F+1215]
# 	RtlGetFullPathName_UEx [0x77C48F6D+1165]

# %%
import urllib.request as request

url = 'blob:https://livrariadigital.aflip.in/325a87c3-9a00-497e-a929-d1c981116e99'
url = 'http://www.xetra.com/blob/1193366/b2f210876702b8e08e40b8ecb769a02e/data/All-tradable-ETFs-ETCs-and-ETNs.xlsx'
# fake user agent of Safari
fake_useragent = 'Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25'
r = request.Request(url, headers={'User-Agent': fake_useragent})
f = request.urlopen(r)

# print or write
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 fake_useragent = 'Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25'
#       7 r = request.Request(url, headers={'User-Agent': fake_useragent})
# ----> 8 f = request.urlopen(r)
#      10 # print or write
#      11 print(f.read())
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:555, in OpenerDirector.error(self, proto, *args)
#     553     http_err = 0
#     554 args = (dict, proto, meth_name) + args
# --> 555 result = self._call_chain(*args)
#     556 if result:
#     557     return result
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:747, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     744 fp.read()
#     745 fp.close()
# --> 747 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\xgabr\anaconda3\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# Set the path to the ChromeDriver executable
chrome_driver_path = 'chrome.exe'

# Set the debugging port of the running Chrome instance
debugging_port = 9014

# Set the ChromeOptions with the remote debugging port
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument(f'--remote-debugging-port={debugging_port}')

# Set the service with the ChromeDriver and ChromeOptions
service = Service(chrome_driver_path)

# Create the WebDriver instance using the service and options
driver = webdriver.Chrome(service=service, options=chrome_options)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[6], line 19
#      16 service = Service(chrome_driver_path)
#      18 # Create the WebDriver instance using the service and options
# ---> 19 driver = webdriver.Chrome(service=service, options=chrome_options)
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py:80, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      77 if not service:
#      78     service = Service(executable_path, port, service_args, service_log_path)
# ---> 80 super().__init__(
#      81     DesiredCapabilities.CHROME["browserName"],
#      82     "goog",
#      83     port,
#      84     options,
#      85     service_args,
#      86     desired_capabilities,
#      87     service_log_path,
#      88     service,
#      89     keep_alive,
#      90 )
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py:101, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      98     raise AttributeError("service cannot be None")
#     100 self.service = service
# --> 101 self.service.start()
#     103 try:
#     104     super().__init__(
#     105         command_executor=ChromiumRemoteConnection(
#     106             remote_server_addr=self.service.service_url,
#    (...)
#     112         options=options,
#     113     )
#
# File c:\Users\xgabr\anaconda3\lib\site-packages\selenium\webdriver\common\service.py:113, in Service.start(self)
#     111 sleep(0.5)
#     112 if count == 60:
# --> 113     raise WebDriverException(f"Can not connect to the Service {self.path}")
#
# WebDriverException: Message: Can not connect to the Service chrome.exe

# %%
from selenium.webdriver.common.by import By
from time import sleep
import re
import glob
import os
import json
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
# %load_ext autoreload
# %load_ext dotenv
# %autoreload
# %dotenv ../.env

chrome_options = Options()
chrome_options.add_experimental_option("debuggerAddress", "127.0.0.1:9014")
driver = webdriver.Chrome(options=chrome_options)
DOWNLOAD_FOLDER = '../downloads'
title = current = button = paginator = page_els = ''
nome_atual = ''
JSON_FILE = 'linkas.json'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv
# cannot find .env file

# %%
driver.get('https://www.livrariadigital.org/pt/post/c-g-jung-os-livros-negros')

# %%
actual_page = 195

driver.switch_to.default_content()
driver.switch_to.frame(driver.find_element(By.CSS_SELECTOR, 'iframe[title="remote content"]'))
driver.switch_to.frame(driver.find_element(By.CSS_SELECTOR, 'iframe.fp-iframe'))

while True:
    try:
        sleep(4)
        print(f'[page="{actual_page}"] img')
        # iframe = driver.find_element(By.CSS_SELECTOR, f'iframe[title="remote content"]')
        image = driver.find_element(By.CSS_SELECTOR, f'[page="{actual_page}"] img')
        # image = driver.find_element(By.CSS_SELECTOR, f'.gradient')
        # image = iframe.find_element(By.CSS_SELECTOR, f'html')
        image.screenshot(f'./images/img{actual_page}.png')
        if actual_page % 2 == 1:
            print('Entrou')
            driver.find_element(By.CSS_SELECTOR, '.next-button.btnNext').click()
        actual_page += 1
    except Exception as e:
        print('Deu um erro!')
        print(e)
        print('Saindo do laço while..')
        break
driver.switch_to.default_content()
# Out:
# [page="195"] img
# Entrou
# [page="196"] img
# [page="197"] img
# Entrou
# [page="198"] img
# [page="199"] img
# Entrou
# [page="200"] img
# [page="201"] img
# Entrou
# [page="202"] img
# [page="203"] img
# Entrou
# [page="204"] img
# [page="205"] img
# Entrou
# [page="206"] img
# [page="207"] img
# Entrou
# [page="208"] img
# [page="209"] img
# Entrou
# [page="210"] img
# [page="211"] img
# Entrou
# [page="212"] img
# [page="213"] img
# Entrou
# [page="214"] img
# [page="215"] img
# Entrou
# [page="216"] img
# [page="217"] img
# Entrou
# [page="218"] img
# [page="219"] img
# Entrou
# [page="220"] img
# [page="221"] img
# Entrou
# [page="222"] img
# [page="223"] img
# Entrou
# [page="224"] img
# [page="225"] img
# Entrou
# [page="226"] img
# [page="227"] img
# Entrou
# [page="228"] img
# [page="229"] img
# Entrou
# [page="230"] img
# [page="231"] img
# Entrou
# [page="232"] img
# [page="233"] img
# Entrou
# [page="234"] img
# [page="235"] img
# Entrou
# [page="236"] img
# [page="237"] img
# Entrou
# [page="238"] img
# [page="239"] img
# Entrou
# [page="240"] img
# [page="241"] img
# Entrou
# [page="242"] img
# [page="243"] img
# Entrou
# [page="244"] img
# [page="245"] img
# Entrou
# [page="246"] img
# [page="247"] img
# Entrou
# [page="248"] img
# [page="249"] img
# Entrou
# [page="250"] img
# [page="251"] img
# Entrou
# [page="252"] img
# [page="253"] img
# Entrou
# [page="254"] img
# [page="255"] img
# Entrou
# [page="256"] img
# [page="257"] img
# Entrou
# [page="258"] img
# [page="259"] img
# Entrou
# [page="260"] img
# [page="261"] img
# Entrou
# [page="262"] img
# [page="263"] img
# Entrou
# [page="264"] img
# [page="265"] img
# Entrou
# [page="266"] img
# [page="267"] img
# Entrou
# [page="268"] img
# [page="269"] img
# Entrou
# [page="270"] img
# [page="271"] img
# Entrou
# [page="272"] img
# [page="273"] img
# Entrou
# [page="274"] img
# [page="275"] img
# Entrou
# [page="276"] img
# [page="277"] img
# Entrou
# [page="278"] img
# [page="279"] img
# Entrou
# [page="280"] img
# [page="281"] img
# Entrou
# [page="282"] img
# [page="283"] img
# Entrou
# [page="284"] img
# [page="285"] img
# Entrou
# [page="286"] img
# [page="287"] img
# Entrou
# [page="288"] img
# [page="289"] img
# Entrou
# [page="290"] img
# [page="291"] img
# Entrou
# [page="292"] img
# [page="293"] img
# Entrou
# [page="294"] img
# [page="295"] img
# Entrou
# [page="296"] img
# [page="297"] img
# Entrou
# [page="298"] img
#   (Session info: chrome=114.0.5735.134)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00B5A813+48355]
# 	(No symbol) [0x00AEC4B1]
# 	(No symbol) [0x009F5220]
# 	(No symbol) [0x00A21846]
# 	(No symbol) [0x00A19F5C]
# 	(No symbol) [0x00A3A73C]
# 	(No symbol) [0x00A19A36]
# 	(No symbol) [0x00A3AA94]
# 	(No symbol) [0x00A4C922]
# 	(No symbol) [0x00A3A536]
# 	(No symbol) [0x00A182DC]
# 	(No symbol) [0x00A193DD]
# 	GetHandleVerifier [0x00DBAABD+2539405]
# 	GetHandleVerifier [0x00DFA78F+2800735]
# 	GetHandleVerifier [0x00DF456C+2775612]
# 	GetHandleVerifier [0x00BE51E0+616112]
# 	(No symbol) [0x00AF5F8C]
# 	(No symbol) [0x00AF2328]
# 	(No symbol) [0x00AF240B]
# 	(No symbol) [0x00AE4FF7]
# 	BaseThreadInitThunk [0x764B6BA9+25]
# 	RtlGetFullPathName_UEx [0x77C48F9F+1215]
# 	RtlGetFullPathName_UEx [0x77C48F6D+1165]
#
# Saindo do laço while..

# %%
from fpdf import FPDF
import os

def append_images_to_pdf(directory, output_file):
    pdf = FPDF()
    filenames = os.listdir(directory)
    filenames.sort(key=lambda x: int(x.split('.')[0].replace('img', '')))
    for filename in filenames:
        print(filename)
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_path = os.path.join(directory, filename)
            pdf.add_page()
            pdf.image(image_path, x=10, y=10, w=190)

    pdf.output(output_file)

# Example usage
directory_path = "./images"
output_pdf = "./os_livros_negros.pdf"
append_images_to_pdf(directory_path, output_pdf)
# Out:
# img1.png
# img2.png
# img3.png
# img4.png
# img5.png
# img6.png
# img7.png
# img8.png
# img9.png
# img10.png
# img11.png
# img12.png
# img13.png
# img14.png
# img15.png
# img16.png
# img17.png
# img18.png
# img19.png
# img20.png
# img21.png
# img22.png
# img23.png
# img24.png
# img25.png
# img26.png
# img27.png
# img28.png
# img29.png
# img30.png
# img31.png
# img32.png
# img33.png
# img34.png
# img35.png
# img36.png
# img37.png
# img38.png
# img39.png
# img40.png
# img41.png
# img42.png
# img43.png
# img44.png
# img45.png
# img46.png
# img47.png
# img48.png
# img49.png
# img50.png
# img51.png
# img52.png
# img53.png
# img54.png
# img55.png
# img56.png
# img57.png
# img58.png
# img59.png
# img60.png
# img61.png
# img62.png
# img63.png
# img64.png
# img65.png
# img66.png
# img67.png
# img68.png
# img69.png
# img70.png
# img71.png
# img72.png
# img73.png
# img74.png
# img75.png
# img76.png
# img77.png
# img78.png
# img79.png
# img80.png
# img81.png
# img82.png
# img83.png
# img84.png
# img85.png
# img86.png
# img87.png
# img88.png
# img89.png
# img90.png
# img91.png
# img92.png
# img93.png
# img94.png
# img95.png
# img96.png
# img97.png
# img98.png
# img99.png
# img100.png
# img101.png
# img102.png
# img103.png
# img104.png
# img105.png
# img106.png
# img107.png
# img108.png
# img109.png
# img110.png
# img111.png
# img112.png
# img113.png
# img114.png
# img115.png
# img116.png
# img117.png
# img118.png
# img119.png
# img120.png
# img121.png
# img122.png
# img123.png
# img124.png
# img125.png
# img126.png
# img127.png
# img128.png
# img129.png
# img130.png
# img131.png
# img132.png
# img133.png
# img134.png
# img135.png
# img136.png
# img137.png
# img138.png
# img139.png
# img140.png
# img141.png
# img142.png
# img143.png
# img144.png
# img145.png
# img146.png
# img147.png
# img148.png
# img149.png
# img150.png
# img151.png
# img152.png
# img153.png
# img154.png
# img155.png
# img156.png
